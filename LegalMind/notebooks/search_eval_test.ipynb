# %% [markdown]
# ### ELASTIC_SEARCH

# %%
from elasticsearch import Elasticsearch

# -----------------------
# Connect to ES 8.x server
# -----------------------
es_client = Elasticsearch(
    "http://localhost:9200",
    request_timeout=30
)

# %%
# -----------------------
# Define mappings
# -----------------------

# For collection_new and collection_old (normal text chunks)
index_settings_chunks = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "chunk_id": {"type": "keyword"},
            "doc_id": {"type": "keyword"},
            "text": {"type": "text"},
            "metadata": {
                "properties": {
                    "chapter": {"type": "text"},
                    "section_number": {"type": "keyword"},
                    "section_title": {"type": "text"},
                    "law_name": {"type": "keyword"}
                }
            }
        }
    }
}

# For collection_map (different schema: mapping between laws)
index_settings_map = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "source_file": {"type": "keyword"},
            "chunk_id": {"type": "keyword"},
            "fields": {
                "properties": {
                    "New_Law_Section": {"type": "keyword"},
                    "Old_Law_Section": {"type": "keyword"},
                    "Subject": {"type": "text"},
                    "Summary_of_comparison": {"type": "text"}
                }
            }
        }
    }
}

# -----------------------
# Create 3 separate indices
# -----------------------
collections = {
    "collection_new": index_settings_chunks,
    "collection_old": index_settings_chunks,
    "collection_map": index_settings_map
}

for idx, settings in collections.items():
    if not es_client.indices.exists(index=idx):
        es_client.indices.create(
            index=idx,
            settings=settings["settings"],
            mappings=settings["mappings"]
        )
        print(f"Index {idx} created successfully!")
    else:
        print(f"Index {idx} already exists. Skipping creation.")
# Out:
# Index collection_new already exists. Skipping creation.
# Index collection_old already exists. Skipping creation.
# Index collection_map already exists. Skipping creation.

# %%
from tqdm.auto import tqdm

# %%
import json
import os
collection_files = {
    "collection_new": ["bns.json", "bnss.json", "bsa.json"],
    "collection_old": ["ipc.json", "crpc.json", "iea.json"],
    "collection_map": ["mapping_of_laws.json"]
}

data_dir = "../data"

# -----------------------
# Load and index documents
# -----------------------
for collection, files in collection_files.items():
    for fname in files:
        file_path = os.path.join(data_dir, fname)
        with open(file_path, "r", encoding="utf-8") as f:
            documents = json.load(f)

        for doc in tqdm(documents, desc=f"Indexing {fname} into {collection}"):
            es_client.index(index=collection, document=doc,timeout="300s")
# Out:
# Indexing bns.json into collection_new:   0%|          | 0/450 [00:00<?, ?it/s]
# Indexing bnss.json into collection_new:   0%|          | 0/1176 [00:00<?, ?it/s]
# Indexing bsa.json into collection_new:   0%|          | 0/164 [00:00<?, ?it/s]
# Indexing ipc.json into collection_old:   0%|          | 0/1271 [00:00<?, ?it/s]
# Indexing crpc.json into collection_old:   0%|          | 0/1946 [00:00<?, ?it/s]
# Indexing iea.json into collection_old:   0%|          | 0/467 [00:00<?, ?it/s]
# Indexing mapping_of_laws.json into collection_map:   0%|          | 0/1237 [00:00<?, ?it/s]

# %%
def elastic_search_all(query):
    """
    Runs the same search query on:
      - collection_new
      - collection_old
      - mapping_of_laws
    Returns combined results from all three.
    """

    # --- Search 1: collection_new ---
    search_new = {
        "size": 10,
        "query": {
            "bool": {
                "must": [{
                    "multi_match": {
                        "query": query,
                        "fields": [
                            "text^3",
                            "metadata.section_title",
                            "metadata.section_number",
                            "metadata.law_name"
                        ],
                        "type": "best_fields"
                    }
                }]
            }
        }
    }
    resp_new = es_client.search(index="collection_new", query=search_new["query"], size=search_new["size"])
    results_new = [hit["_source"] for hit in resp_new["hits"]["hits"]]

    # --- Search 2: collection_old ---
    search_old = {
        "size": 5,
        "query": {
            "bool": {
                "must": [{
                    "multi_match": {
                        "query": query,
                        "fields": [
                            "text^3",
                            "metadata.section_title",
                            "metadata.section_number",
                            "metadata.law_name"
                        ],
                        "type": "best_fields"
                    }
                }]
            }
        }
    }
    resp_old = es_client.search(index="collection_old", query=search_old["query"], size=search_old["size"])
    results_old = [hit["_source"] for hit in resp_old["hits"]["hits"]]

    search_map = {
        "size": 5,
        "query": {
            "bool": {
                "must": [{
                    "multi_match": {
                        "query": query,
                        "fields": [
                            "fields.New_Law_Section^3",
                            "fields.Old_Law_Section^3",
                            "fields.Subject",
                            "fields.Summary_of_comparison"
                        ],
                        "type": "best_fields"
                    }
                }]
            }
        }
    }
    resp_map = es_client.search(index="collection_map", query=search_map["query"], size=search_map["size"])
    results_map = [hit["_source"] for hit in resp_map["hits"]["hits"]]

    # --- Combined results ---
    combined_results = {
        "collection_new": results_new,
        "collection_old": results_old,
        "collection_map": results_map  # key updated here
    }

    return combined_results

# %% [markdown]
# ### VECTOR_SEARCH

# %%
import os
import json
import uuid
from fastembed import TextEmbedding
from qdrant_client import QdrantClient, models

# -----------------------
# CONFIGURATION
# -----------------------
data_dir = "../data"
VECTOR_SIZE = 1024  # bge-large-en-v1.5 has 1024-dimension embeddings
BATCH_SIZE = 32

# %%
# Initialize Qdrant client
qd_client = QdrantClient("http://localhost:6333")

# %%
# Initialize embedding model
model_handle = TextEmbedding(model_name="BAAI/bge-large-en-v1.5")

# %%
# Collections
collection_new = "collection_new"
collection_old = "collection_old"
collection_map = "collection_map"

# %%
# -----------------------
# Ensure collection exists
# -----------------------
def ensure_collection_exists(qd_client, collection_name, vector_size=VECTOR_SIZE):
    if not qd_client.collection_exists(collection_name):
        print(f"⚙️ Creating collection: {collection_name}")
        qd_client.create_collection(
            collection_name=collection_name,
            vectors_config=models.VectorParams(
                size=vector_size,
                distance=models.Distance.COSINE
            )
        )
    else:
        info = qd_client.get_collection(collection_name)
        print(f"✅ Collection '{collection_name}' already exists with {info.vectors_count} vectors.")

# -----------------------
# COLLECTIONS & FILES
# -----------------------
collection_files = {
    collection_new: ["bns.json", "bnss.json", "bsa.json"],
    collection_old: ["ipc.json", "crpc.json", "iea.json"],
    collection_map: ["mapping_of_laws.json"]
}

# -----------------------
# LOAD & UPSERT INTO QDRANT
# -----------------------
for collection, files in collection_files.items():
    ensure_collection_exists(qd_client, collection)

    for fname in files:
        file_path = os.path.join(data_dir, fname)
        if not os.path.exists(file_path):
            print(f"⚠️ File not found: {file_path}")
            continue

        with open(file_path, "r", encoding="utf-8") as f:
            documents = json.load(f)

        for start in range(0, len(documents), BATCH_SIZE):
            batch_docs = documents[start:start + BATCH_SIZE]
            points = []

            # Prepare texts for embedding
            texts = [
                doc.get("text", "") if collection in [collection_new, collection_old]
                else json.dumps(doc, ensure_ascii=False)
                for doc in batch_docs
            ]

            # Generate embeddings for the batch
            vectors = list(model_handle.embed(texts))
            assert len(vectors) == len(batch_docs)

            for doc, vector in zip(batch_docs, vectors):
                point_id = str(uuid.uuid4())

                payload = {
                    "chunk_id": doc.get("chunk_id"),
                    "doc_id": doc.get("doc_id"),
                    "content": doc.get("text", ""),
                }

                if collection in [collection_new, collection_old]:
                    payload["metadata"] = {
                        "section_number": doc.get("metadata", {}).get("section_number"),
                        "section_title": doc.get("metadata", {}).get("section_title"),
                        "law_name": doc.get("metadata", {}).get("law_name")
                    }
                else:
                    payload.update({
                        "source_file": doc.get("source_file"),
                        "fields": doc.get("fields", {})
                    })

                point = models.PointStruct(id=point_id, vector=vector, payload=payload)
                points.append(point)

            # Upsert to Qdrant
            qd_client.upsert(collection_name=collection, points=points)
            print(f"✅ Indexed {len(points)} documents into {collection} from {fname} (batch {start // BATCH_SIZE + 1})")
# Out:
# ⚙️ Creating new collection: collection_new
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 31, in ensure_collection_exists(qd_client, collection_name, vector_size, vector_name)
#      30 info = qd_client.get_collection(collection_name)
# ---> 31 existing_size = info.vectors[vector_name].size
#      32 if existing_size != vector_size:
#
# File ~/Desktop/llm-project/LegalMind/LegalMind/venv/lib/python3.12/site-packages/pydantic/main.py:1026, in BaseModel.__getattr__(self, item)
#    1024 else:
#    1025     # this is the current error
# -> 1026     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'CollectionInfo' object has no attribute 'vectors'
#
# During handling of the above exception, another exception occurred:
#
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[37], line 48
#      44 # -----------------------
#      45 # Load & index documents
#      46 # -----------------------
#      47 for collection, files in collection_files.items():
# ---> 48     ensure_collection_exists(qd_client, collection)
#      50     for fname in files:
#      51         file_path = os.path.join(data_dir, fname)
#
# Cell In[37], line 39, in ensure_collection_exists(qd_client, collection_name, vector_size, vector_name)
#      37 except Exception:
#      38     print(f"⚙️ Creating new collection: {collection_name}")
# ---> 39     qd_client.create_collection(
#      40         collection_name=collection_name,
#      41         vectors_config={vector_name: models.VectorParams(size=vector_size, distance=models.Distance.COSINE)}
#      42     )
#
# File ~/Desktop/llm-project/LegalMind/LegalMind/venv/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:2382, in QdrantClient.create_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, strict_mode_config, **kwargs)
#    2332 """Create empty collection with given parameters
#    2333
#    2334 Args:
#    (...)   2378     Operation result
#    2379 """
#    2380 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2382 return self._client.create_collection(
#    2383     collection_name=collection_name,
#    2384     vectors_config=vectors_config,
#    2385     shard_number=shard_number,
#    2386     sharding_method=sharding_method,
#    2387     replication_factor=replication_factor,
#    2388     write_consistency_factor=write_consistency_factor,
#    2389     on_disk_payload=on_disk_payload,
#    2390     hnsw_config=hnsw_config,
#    2391     optimizers_config=optimizers_config,
#    2392     wal_config=wal_config,
#    2393     quantization_config=quantization_config,
#    2394     init_from=init_from,
#    2395     timeout=timeout,
#    2396     sparse_vectors_config=sparse_vectors_config,
#    2397     strict_mode_config=strict_mode_config,
#    2398     **kwargs,
#    2399 )
#
# File ~/Desktop/llm-project/LegalMind/LegalMind/venv/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:2815, in QdrantRemote.create_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, sparse_vectors_config, sharding_method, strict_mode_config, **kwargs)
#    2797     init_from = GrpcToRest.convert_init_from(init_from)
#    2799 create_collection_request = models.CreateCollection(
#    2800     vectors=vectors_config,
#    2801     shard_number=shard_number,
#    (...)   2812     strict_mode_config=strict_mode_config,
#    2813 )
# -> 2815 result: Optional[bool] = self.http.collections_api.create_collection(
#    2816     collection_name=collection_name,
#    2817     create_collection=create_collection_request,
#    2818     timeout=timeout,
#    2819 ).result
#    2821 assert result is not None, "Create collection returned None"
#    2822 return result
#
# File ~/Desktop/llm-project/LegalMind/LegalMind/venv/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:294, in SyncCollectionsApi.create_collection(self, collection_name, timeout, create_collection)
#     285 def create_collection(
#     286     self,
#     287     collection_name: str,
#     288     timeout: int = None,
#     289     create_collection: m.CreateCollection = None,
#     290 ) -> m.InlineResponse200:
#     291     """
#     292     Create new collection with given parameters
#     293     """
# --> 294     return self._build_for_create_collection(
#     295         collection_name=collection_name,
#     296         timeout=timeout,
#     297         create_collection=create_collection,
#     298     )
#
# File ~/Desktop/llm-project/LegalMind/LegalMind/venv/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:96, in _CollectionsApi._build_for_create_collection(self, collection_name, timeout, create_collection)
#      94 if "Content-Type" not in headers:
#      95     headers["Content-Type"] = "application/json"
# ---> 96 return self.api_client.request(
#      97     type_=m.InlineResponse200,
#      98     method="PUT",
#      99     url="/collections/{collection_name}",
#     100     headers=headers if headers else None,
#     101     path_params=path_params,
#     102     params=query_params,
#     103     content=body,
#     104 )
#
# File ~/Desktop/llm-project/LegalMind/LegalMind/venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File ~/Desktop/llm-project/LegalMind/LegalMind/venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 409 (Conflict)
# Raw response content:
# b'{"status":{"error":"Wrong input: Collection `collection_new` already exists!"},"time":0.002103127}'

# %%
def vector_search(question):
    print("⚙️ Running vector_search...")

    # --- Search in collection_new (10 results) ---
    query_points_new = qd_client.query_points(
        collection_name=collection_new,
        query=models.Document(
            text=question,
            model=model_handle
        ),
        limit=10,
        with_payload=True
    )

    # --- Search in collection_old (5 results) ---
    query_points_old = qd_client.query_points(
        collection_name=collection_old,
        query=models.Document(
            text=question,
            model=model_handle
        ),
        limit=5,
        with_payload=True
    )

    # --- Search in collection_map (5 results) ---
    query_points_map = qd_client.query_points(
        collection_name=collection_map,
        query=models.Document(
            text=question,
            model=model_handle
        ),
        limit=5,
        with_payload=True
    )

    # Collect all results
    results_new = [{"source": "new", "payload": p.payload} for p in query_points_new.points]
    results_old = [{"source": "old", "payload": p.payload} for p in query_points_old.points]
    results_map = [{"source": "map", "payload": p.payload} for p in query_points_map.points]

    # Combine all results
    combined_results = results_new + results_old + results_map

    print(f"✅ Retrieved {len(results_new)} (new) + {len(results_old)} (old) + {len(results_map)} (map) results.")
    return combined_results

# %% [markdown]
# #### Save questions to csv file

# %%
import pandas as pd
import json
import os
from tqdm import tqdm

# ----------------------------------------------------
# 1. Define the file paths
# ----------------------------------------------------
file_names = [
    "../data/questions/llm_questions_mapping.json",
    "../data/questions/llm_questions_newlaws.json",
    "../data/questions/llm_questions_oldlaws.json"
]

# ----------------------------------------------------
# 2. Helper function to infer collection from filename
# ----------------------------------------------------
def infer_collection_from_filename(file_path):
    file_name = os.path.basename(file_path).lower()
    if "mapping" in file_name:
        return "collection_map"
    elif "newlaws" in file_name:
        return "collection_new"
    elif "oldlaws" in file_name:
        return "collection_old"
    else:
        return "unknown_collection"

# ----------------------------------------------------
# 3. Function to load questions from a JSON file
# ----------------------------------------------------
def load_questions_with_chunk_id_as_q_id(file_path):
    all_records = []
    collection = infer_collection_from_filename(file_path)

    try:
        with open(file_path, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        raise FileNotFoundError(f"File not found at: {file_path}")

    for entry in data:
        q_id = entry.get("chunk_id", "NO_CHUNK_ID")
        questions = entry.get("llm_questions", [])
        for question in questions:
            all_records.append({
                "q_id": q_id,
                "question": question,
                "collection": collection
            })
    return all_records

# ----------------------------------------------------
# 4. Load and process all files
# ----------------------------------------------------
all_questions = []
for file_name in file_names:
    try:
        all_questions.extend(load_questions_with_chunk_id_as_q_id(file_name))
        print(f"✅ Successfully loaded: {file_name}")
    except FileNotFoundError:
        print(f"❌ ERROR: File not found: {file_name}. Please check the path.")
    except Exception as e:
        print(f"❌ An error occurred processing {file_name}: {e}")

# ----------------------------------------------------
# 5. Create a Pandas DataFrame
# ----------------------------------------------------
if all_questions:
    df = pd.DataFrame(all_questions)

    print("\n" + "=" * 40)
    print("DataFrame Created Successfully:")
    print("=" * 40)
    print(df.head(5))
    print("-" * 40)
    print(f"Total rows in DataFrame: {len(df)}")
    print(f"Number of unique chunk_id/q_id values: {df['q_id'].nunique()}")
    print(f"Collections present: {df['collection'].unique()}")
else:
    print("\nDataFrame creation failed: No data was loaded.")

# ----------------------------------------------------
# 6. Optional: save combined data to CSV
# ----------------------------------------------------
output_csv_path = "../data/all-questions.csv"
df.to_csv(output_csv_path, index=False)
print(f"\n✅ Combined questions saved to {output_csv_path}")
# Out:
# ✅ Successfully loaded: ../data/questions/llm_questions_mapping.json
# ✅ Successfully loaded: ../data/questions/llm_questions_newlaws.json
# ✅ Successfully loaded: ../data/questions/llm_questions_oldlaws.json
#
# ========================================
# DataFrame Created Successfully:
# ========================================
#                q_id                                           question  \
# 0  BNSS_to_CrPC_268  What does the chunk_id BNSS_to_CrPC_268 imply ...
# 1  BNSS_to_CrPC_268  In the absence of textual content, what type o...
# 2  BNSS_to_CrPC_268  If you were to populate this chunk with CrPC s...
# 3  BNSS_to_CrPC_268  How would you annotate this chunk to indicate ...
# 4  BNSS_to_CrPC_268  What metadata fields would be necessary to loc...
#
#        collection
# 0  collection_map
# 1  collection_map
# 2  collection_map
# 3  collection_map
# 4  collection_map
# ----------------------------------------
# Total rows in DataFrame: 6700
# Number of unique chunk_id/q_id values: 1279
# Collections present: ['collection_map' 'collection_new' 'collection_old']
#
# ✅ Combined questions saved to ../data/all-questions.csv

# %%
import os

# Make sure the directory exists
os.makedirs("../data", exist_ok=True)

# Save the DataFrame
df.to_csv("../data/all-questions.csv", index=False)
print("Saved to ../data/all-questions.csv")
# Out:
# Saved to ../data/all-questions.csv

# %%
df_allquestions = pd.read_csv('../data/all-questions.csv')
all_questions = df_allquestions.to_dict(orient='records')
all_questions
# Out:
# [{'q_id': 'BNSS_to_CrPC_268',
#   'question': 'What does the chunk_id BNSS_to_CrPC_268 imply about the source and target statutes involved?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_268',
#   'question': 'In the absence of textual content, what type of questions would be most appropriate to evaluate the BNSS_to_CrPC_268 mapping?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_268',
#   'question': 'If you were to populate this chunk with CrPC section 268 content, what would be the most likely legal issue area to focus on?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_268',
#   'question': 'How would you annotate this chunk to indicate its empty text and its purpose within a larger dataset?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_268',
#   'question': 'What metadata fields would be necessary to locate the actual legal text corresponding to BNSS_to_CrPC_268 in a repository?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_132(3)',
#   'question': "What is the value of the 'chunk_id' field in the provided JSON chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_132(3)',
#   'question': "What is the value of the 'doc_id' field in the provided JSON chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_132(3)',
#   'question': "What is the value of the 'text' field in the provided JSON chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_132(3)',
#   'question': "Does the 'metadata' object contain any keys, and if so, what are they?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_132(3)',
#   'question': "What components make up the 'chunk_id' value 'BSA_to_IEA_132(3)', and what might they signify about the source and section?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_197',
#   'question': 'What is the chunk_id of the dataset entry labeled BNSS_to_CrPC_197?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_197',
#   'question': 'Is there any textual content provided under the "text" field for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_197',
#   'question': 'What is the value of the "doc_id" field in the chunk\'s JSON?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_197',
#   'question': 'Which keys are present inside the "metadata" object of this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_197',
#   'question': 'What is the current value of the "text" property in this chunk\'s payload?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_115\n(2)',
#   'question': "What is the exact value of the 'chunk_id' field in this JSON fragment, including any newline characters?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_115\n(2)',
#   'question': "Does the 'text' field in this chunk contain any actual legal text?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_115\n(2)',
#   'question': "What is the value of the 'doc_id' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_115\n(2)',
#   'question': "What is the content of the 'metadata' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_115\n(2)',
#   'question': "In the chunk_id 'BNS_to_IPC_115 (2)', what is the numeric component and what might the '(2)' denote in a labeling scheme?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_527',
#   'question': 'What is the exact value of the "chunk_id" field for this legal text chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_527',
#   'question': 'What is the value of the "doc_id" field in the provided chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_527',
#   'question': 'What is the value of the "text" field in the provided chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_527',
#   'question': 'What does the "metadata" field contain in this chunk (is it empty or populated)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_527',
#   'question': 'How many keys are present in the "metadata" field of this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_509',
#   'question': "What is the actual legal text contained in BNSS_to_CrPC_509, given the 'text' field is empty in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_509',
#   'question': "Are there any section numbers, articles, or abbreviations defined in the BNSS_to_CrPC_509 chunk's metadata that should guide question generation?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_509',
#   'question': 'Does BNSS_to_CrPC_509 propose a cross-reference between BNSS and the Criminal Procedure Code (CrPC), and if so, which sections or articles would be implicated?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_509',
#   'question': 'What is the official title of the document represented by BNSS_to_CrPC_509 and its jurisdiction?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_509',
#   'question': 'Do the metadata fields in BNSS_to_CrPC_509 specify any act year, country, or statutory source that should inform the questions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_358',
#   'question': 'What is the chunk_id of the provided legal text snippet?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_358',
#   'question': "Does the 'text' field contain any content in chunk BNS_to_IPC_358?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_358',
#   'question': 'What is the value of the doc_id field for chunk BNS_to_IPC_358?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_358',
#   'question': "What are the values of the 'metadata' field in the chunk BNS_to_IPC_358?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_358',
#   'question': "Are there any section numbers, law titles, or abbreviations present in the 'text' field of chunk BNS_to_IPC_358?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_116',
#   'question': "BNSS_to_CrPC_116 has an empty 'text' field. What exact types of content would you need to populate to generate content-specific questions for this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_116',
#   'question': 'Given the chunk ID BNSS_to_CrPC_116, what CrPC section reference would you expect to be associated with it, and how would you verify it once content is added?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_116',
#   'question': 'Which metadata fields (e.g., doc_id, metadata keys) are essential for BNSS_to_CrPC_116 to support automated question generation when the current fields are empty?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_116',
#   'question': 'Describe a workflow to populate BNSS_to_CrPC_116 from an external legal corpus so that five self-contained, content-based questions can be produced.',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_116',
#   'question': "Propose a minimal schema extension or data model that would allow BNSS_to_CrPC_116 to be used for generating precise questions even if the initial 'text' is blank.",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_65',
#   'question': 'What is the intended legal scope of the cross-reference labeled BSA_to_IEA_65 in this dataset?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_65',
#   'question': 'Which section numbers or statute abbreviations would you expect to accompany BSA_to_IEA_65 to locate the linked provisions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_65',
#   'question': 'If BSA_to_IEA_65 denotes a cross-reference between two regulatory frameworks, which two frameworks are being cross-mapped?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_65',
#   'question': 'What metadata fields would you expect to accompany an empty chunk to enable precise question generation about BSA_to_IEA_65?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_65',
#   'question': 'How would you verify, once the text is provided, that questions generated for BSA_to_IEA_65 correctly map to the linked BSA and IEA provisions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_50',
#   'question': 'Based on the chunk_id BNS_to_IPC_50, which two legal codes or systems are indicated to be cross-referenced?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_50',
#   'question': 'If IPC stands for the Indian Penal Code, what type of provisions would a BNS_to_IPC cross-reference typically connect from BNS to IPC?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_50',
#   'question': 'What citation format is expected for IPC sections within a document labeled BNS_to_IPC_50?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_50',
#   'question': 'What might the suffix "_50" denote in the chunk_id BNS_to_IPC_50 with respect to cross-reference mappings?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_50',
#   'question': 'What minimum metadata would you require from the chunk to determine its legal scope, given only the chunk_id?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(26)',
#   'question': 'What is the exact value of the chunk_id field for this legal text chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(26)',
#   'question': 'What is the value contained in the doc_id field?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(26)',
#   'question': 'What is the value of the text field for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(26)',
#   'question': 'What is the content of the metadata field for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(26)',
#   'question': "What are the top-level keys in this chunk's JSON object?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_123',
#   'question': 'Which two legal instruments are connected by the crosswalk labeled BNS_to_IPC_123?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_123',
#   'question': 'Does this chunk contain any explicit one-to-one mappings between BNS provisions and IPC sections?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_123',
#   'question': 'What fields are currently present in the chunk (doc_id, text, metadata) and what are their values?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_123',
#   'question': 'If you were to populate the text for BNS_to_IPC_123, what elements would you include to establish clear cross-references (e.g., BNS identifiers, IPC identifiers, notes)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_123',
#   'question': 'What edition or versioning information would typically accompany a crosswalk like BNS_to_IPC_123 in a legal database?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_148',
#   'question': 'What is the value of the chunk_id field for this dataset element?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_148',
#   'question': 'What is the value of the doc_id field for chunk_id BSA_to_IEA_148?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_148',
#   'question': 'What is the content of the text field for chunk_id BSA_to_IEA_148?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_148',
#   'question': 'What is the content of the metadata field for chunk_id BSA_to_IEA_148?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_148',
#   'question': 'What keys exist within the metadata object for chunk_id BSA_to_IEA_148?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_75',
#   'question': 'What is the chunk_id value for this legal text chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_75',
#   'question': "Is the 'text' field populated in this chunk (BSA_to_IEA_75)?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_75',
#   'question': "What is the value of the 'doc_id' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_75',
#   'question': "What does the 'metadata' field contain for this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_75',
#   'question': "How many top-level keys are present in this chunk's JSON structure?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_121 (2)',
#   'question': 'What is the exact value of the chunk_id field in the provided chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_121 (2)',
#   'question': 'Does the text field of the chunk contain any legal text content?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_121 (2)',
#   'question': 'What is the value of doc_id for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_121 (2)',
#   'question': 'What is the content of the metadata field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_121 (2)',
#   'question': 'Given that the text field is empty, what implications does that have for generating law-questions directly from this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_306',
#   'question': "What is the exact value of the 'chunk_id' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_306',
#   'question': "Is the 'text' field in this chunk empty or non-empty, and what is its content?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_306',
#   'question': "What is the value of the 'doc_id' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_306',
#   'question': "What does the 'metadata' field contain for this chunk (e.g., its keys or lack thereof)?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_306',
#   'question': "List the top-level keys present in this chunk's JSON object.",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_181',
#   'question': 'What is the objective implied by the chunk identifier BNSS_to_CrPC_181?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_181',
#   'question': 'Which statutes or sections would you expect to see referenced in a BNSS_to_CrPC_181 cross-reference?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_181',
#   'question': 'How should BNSS_to_CrPC_181 handle amendments if this chunk involves CrPC changes?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_181',
#   'question': 'What metadata would clarify the scope and applicability of BNSS_to_CrPC_181 in a legal database?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_181',
#   'question': 'Which authorities or sources would you consult to interpret BNSS_to_CrPC_181 when the text is not provided?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_172',
#   'question': "In this chunk, what is the value of the 'chunk_id' field?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_172',
#   'question': "What is the value of the 'doc_id' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_172',
#   'question': "What content is currently stored in the 'text' field of this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_172',
#   'question': "What is the value of the 'metadata' field for this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_172',
#   'question': "What are the top-level fields present in this chunk's JSON object?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_361',
#   'question': 'What is the exact chunk_id value assigned to this legal text fragment?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_361',
#   'question': "Does the 'text' field in this chunk contain any substantive content?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_361',
#   'question': "What is the value of the 'doc_id' field in the chunk's JSON?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_361',
#   'question': "Is the 'metadata' object populated with entries for this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_361',
#   'question': 'What are the top-level keys of this JSON chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_280',
#   'question': "In the JSON for chunk_id 'BNS_to_IPC_280', what is the value of the 'doc_id' field?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_280',
#   'question': "Does the 'text' field contain any content for the chunk 'BNS_to_IPC_280'?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_280',
#   'question': "What are the top-level keys in the chunk JSON object for 'BNS_to_IPC_280'?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_280',
#   'question': "What is the value of the 'metadata' field for this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_280',
#   'question': "What is the exact value of the 'chunk_id' field in this JSON?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_77',
#   'question': 'List any CrPC section numbers referenced in BNSS_to_CrPC_77.',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_77',
#   'question': 'Identify the primary legal topic area BNSS_to_CrPC_77 is intended to govern (e.g., arrests, warrants, trials).',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_77',
#   'question': 'Does BNSS_to_CrPC_77 include any defined terms that alter standard CrPC interpretation?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_77',
#   'question': 'Are there cross-references to other statutes within BNSS_to_CrPC_77?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_77',
#   'question': "What is the recommended approach to handle an empty 'text' field in BNSS_to_CrPC_77 when generating questions?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_138',
#   'question': 'What is the chunk_id of this legal text chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_138',
#   'question': "Does the 'text' field for chunk BSA_to_IEA_138 contain any substantive content?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_138',
#   'question': "Are there any non-empty values in the 'doc_id' or 'metadata' fields for chunk BSA_to_IEA_138?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_138',
#   'question': "When the 'text' field is empty, what steps should a legal question generator take to create five questions for chunk BSA_to_IEA_138?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_138',
#   'question': "If you must still provide five questions for BSA_to_IEA_138, propose a set of five question templates that do not rely on the chunk's substantive text.",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_73',
#   'question': 'In BNSS_to_CrPC_73, which law title or abbreviations indicate a mapping from BNSS to the CrPC?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_73',
#   'question': 'What CrPC sections or BNSS references are said to be affected by BNSS_to_CrPC_73?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_73',
#   'question': 'Does BNSS_to_CrPC_73 establish transitional provisions, amendments, or repeals to the CrPC, and which are they?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_73',
#   'question': 'Is there an enactment date, citation, or regulatory authority linked to BNSS_to_CrPC_73?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_73',
#   'question': 'What is the intended jurisdictional scope of BNSS_to_CrPC_73— nationwide CrPC changes, or specific to a jurisdiction?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_180',
#   'question': 'What is the exact value of the chunk_id field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_180',
#   'question': 'What is the value of the doc_id field in the chunk with chunk_id "BNS_to_IPC_180"?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_180',
#   'question': 'What is the value of the text field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_180',
#   'question': 'Does the metadata object for this chunk contain any keys, and if so, what are they?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_180',
#   'question': "What could the identifier 'BNS_to_IPC_180' suggest about the intended legal mapping or cross-reference for this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_125 (b)',
#   'question': 'What IPC element is suggested by the chunk_id "BNS_to_IPC_125 (b)"?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_125 (b)',
#   'question': 'Is there any substantive text present in this chunk\'s "text" field?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_125 (b)',
#   'question': 'What is the value of the "doc_id" associated with this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_125 (b)',
#   'question': 'Which law title would you consult to understand IPC Section 125(b)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_125 (b)',
#   'question': 'What does the empty "text" field imply about the availability of case content for analysis?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_452',
#   'question': 'What is the value of the "chunk_id" field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_452',
#   'question': 'Is the "text" field in this chunk empty or non-empty?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_452',
#   'question': 'What is the value of the "doc_id" field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_452',
#   'question': 'What is the structure and content of the "metadata" field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_452',
#   'question': 'Does this chunk contain any substantive content such as sections, titles, or abbreviations?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_2(1) (c)',
#   'question': 'What is the stated purpose of the provision identified as BSA_to_IEA_2(1) (c)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_2(1) (c)',
#   'question': 'Which parties are bound by the obligations in BSA_to_IEA_2(1) (c)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_2(1) (c)',
#   'question': 'What actions are required or prohibited by BSA_to_IEA_2(1) (c), and what penalties apply?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_2(1) (c)',
#   'question': 'Does BSA_to_IEA_2(1) (c) include defined terms, and how are they interpreted within the section?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_2(1) (c)',
#   'question': 'What is the effective date of BSA_to_IEA_2(1) (c) and are there any transitional provisions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(29)',
#   'question': 'What is the value of the doc_id field in chunk BNS_to_IPC_2(29)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(29)',
#   'question': "Is there any substantive text present in the 'text' field of chunk BNS_to_IPC_2(29)?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(29)',
#   'question': "Does the 'metadata' object for chunk BNS_to_IPC_2(29) contain any keys or values?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(29)',
#   'question': 'How many top-level keys exist in the JSON object for chunk BNS_to_IPC_2(29), and what are their names?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_2(29)',
#   'question': "If you were to populate the 'text' field with IPC-related content for BNS_to_IPC_2(29), which IPC section would you reference first and why?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_443',
#   'question': 'What is the value of the chunk_id field for this entry?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_443',
#   'question': 'What is the value of the doc_id field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_443',
#   'question': 'What is the value of the text field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_443',
#   'question': 'What is the value of the metadata field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_443',
#   'question': 'Does the chunk contain any substantive legal text to analyze, given that the text field is empty?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_129',
#   'question': 'What is the value of the chunk_id field in this JSON snippet?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_129',
#   'question': 'Does the text field for BNSS_to_CrPC_129 contain any content?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_129',
#   'question': 'What is the value of the doc_id field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_129',
#   'question': 'Does the metadata object in this chunk contain any keys?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_129',
#   'question': 'Which field would you check first if you needed to add actual legal text to BNSS_to_CrPC_129?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_28',
#   'question': 'What is the main subject area addressed by BNSS_to_CrPC_28 (e.g., offenses, proceedings, or enforcement)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_28',
#   'question': 'Which authority has jurisdiction over BNSS_to_CrPC_28 according to the chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_28',
#   'question': 'What condition must be met before BNSS_to_CrPC_28 can be invoked?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_28',
#   'question': 'What remedies or outcomes does BNSS_to_CrPC_28 specify for the parties involved?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_28',
#   'question': 'Does BNSS_to_CrPC_28 reference any other sections or statutes, and if so, which ones?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (1)',
#   'question': 'Which specific statutes or provisions are cited within chunk BNS_to_IPC_324 (1)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (1)',
#   'question': 'Does BNS_to_IPC_324 (1) define any terms, and if so, what terms are defined?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (1)',
#   'question': 'What are the primary obligations, prohibitions, or duties imposed by BNS_to_IPC_324 (1)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (1)',
#   'question': 'What penalties, fines, or remedies are specified for violations in BNS_to_IPC_324 (1)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (1)',
#   'question': 'Are there any exemptions, defenses, or exceptions listed in BNS_to_IPC_324 (1)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (2)',
#   'question': 'In the chunk with chunk_id BNS_to_IPC_341 (2), which IPC section number is indicated by the numeric portion of the ID?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (2)',
#   'question': "What does the prefix BNS_to_IPC suggest about the chunk's intended mapping or relation between legal sources?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (2)',
#   'question': 'Does the text field contain any substantive legal text in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (2)',
#   'question': "What is the value of the doc_id field in the chunk's metadata?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (2)',
#   'question': "What are the top-level keys present in this chunk's JSON structure besides the chunk_id field?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_166',
#   'question': 'What is the value of the chunk_id field for this data item?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_166',
#   'question': 'Is there any textual content present in the "text" field of this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_166',
#   'question': 'What is the value of the "doc_id" field, and is it empty or populated?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_166',
#   'question': 'What does the "metadata" field contain for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_166',
#   'question': 'Based on the identifier "BSA_to_IEA_166", what two acronyms appear to be connected, and what might this indicate about the chunk\'s intended mapping or relationship?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_50',
#   'question': 'What is the implied subject area of the chunk BNSS_to_CrPC_50 based on its identifier?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_50',
#   'question': 'Does BNSS_to_CrPC_50 currently include any statutory text, case law, or commentary in its text field, or is the content empty?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_50',
#   'question': 'If BNSS_to_CrPC_50 represents a mapping to the CrPC, what does CrPC stand for, and what general procedural area would this mapping cover?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_50',
#   'question': 'What metadata fields would be needed alongside BNSS_to_CrPC_50 to generate precise, text-based questions (e.g., jurisdiction, edition, section references)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_50',
#   'question': 'What concrete steps would you take to populate BNSS_to_CrPC_50 with content so that five uniquely tied questions can be created?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(4)',
#   'question': "What does the chunk_id 'BNS_to_IPC_3(4)' indicate about the source code and the specific subsection involved?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(4)',
#   'question': 'Identify the numeric subsection reference embedded in the chunk_id and describe how it would typically appear in a formal legal citation.',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(4)',
#   'question': "Which two legal codes are suggested by the chunk_id through the 'to' linkage, and what does this imply about cross-referencing?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(4)',
#   'question': 'If the chunk were to contain substantive text, which part would you expect to reflect a cross-reference between BNS and IPC?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(4)',
#   'question': 'Aside from the text content, which fields in the provided JSON structure uniquely identify this chunk, and what values do they hold currently?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_153',
#   'question': 'What is the chunk_id value for this legal text chunk in BNSS_to_CrPC_153?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_153',
#   'question': "Does the 'text' field contain any substantive content in this BNSS_to_CrPC_153 chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_153',
#   'question': "What is the value of the 'doc_id' key in this chunk's JSON?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_153',
#   'question': "What information is stored inside the 'metadata' object for BNSS_to_CrPC_153?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_153',
#   'question': 'If a section number or abbreviation were present in the chunk, which fields in this JSON structure would be expected to contain it?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_244',
#   'question': 'What is the chunk_id of the legal material currently being analyzed?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_244',
#   'question': 'If the empty text for BNS_to_IPC_244 were to be populated with statutory language, which IPC title or abbreviation would you expect to reference first?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_244',
#   'question': "What specific gaps would you identify in chunk BNS_to_IPC_244 given that the 'text' field is blank?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_244',
#   'question': 'Which metadata fields present in this chunk would you need to preserve when importing into a legal knowledge base (e.g., doc_id, text, metadata)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_244',
#   'question': 'When future text is added to BNS_to_IPC_244, what is the recommended format to annotate any section numbers or law titles to maintain IPC citation standards?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_294',
#   'question': 'What is the exact value of the chunk_id field for this entry?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_294',
#   'question': 'Does this chunk currently contain any legal text in the text field?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_294',
#   'question': 'What information is missing in the doc_id field that would help identify the source of the legal text for chunk BNS_to_IPC_294?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_294',
#   'question': 'Which fields in the metadata object would you expect to be populated to provide jurisdictional or source details?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_294',
#   'question': 'If you later receive non-empty content for the text field, what immediate steps would you take to generate five distinct, self-contained questions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_374',
#   'question': "What would you expect to find in the 'text' field of BNSS_to_CrPC_374 if it were populated with CrPC content?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_374',
#   'question': "What is the current content of the 'doc_id' field for BNSS_to_CrPC_374, and what would be your next step to locate a source document?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_374',
#   'question': "Does the 'metadata' object accompany BNSS_to_CrPC_374 in this chunk, and what is its current state?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_374',
#   'question': 'Given the chunk_id BNSS_to_CrPC_374, which legal code is it likely intended to reference, and what could be the relation between BNSS and CrPC?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_374',
#   'question': 'What practical steps would you take to obtain or verify the CrPC provisions that BNSS_to_CrPC_374 is supposed to map to?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (5)',
#   'question': 'Which statute and section are identified by the chunk_id BNS_to_IPC_324 (5)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (5)',
#   'question': 'What is the core prohibited conduct under Indian Penal Code Section 324?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (5)',
#   'question': 'What element differentiates Section 324 from other hurt offenses in terms of weapon or means used?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (5)',
#   'question': 'What categories of punishment are associated with IPC Section 324?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (5)',
#   'question': "Which jurisdiction's law contains IPC Section 324?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_58',
#   'question': 'Does the text field in BNSS_to_CrPC_58 contain any non-empty content?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_58',
#   'question': 'Are there any section numbers, law titles, or abbreviations present in BNSS_to_CrPC_58?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_58',
#   'question': 'What is the value of the doc_id field for BNSS_to_CrPC_58?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_58',
#   'question': 'Is the metadata object associated with BNSS_to_CrPC_58 empty?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_58',
#   'question': 'What is the overall status of BNSS_to_CrPC_58 as a source for legal provisions (substantive content present or absent)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_9',
#   'question': "What is the exact value of the 'chunk_id' field for this data entry?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_9',
#   'question': "What is the value of the 'doc_id' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_9',
#   'question': "What is the value of the 'text' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_9',
#   'question': "What is the value of the 'metadata' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_9',
#   'question': "If the 'text' field were populated with legal content, which identifiers (section numbers, law titles, or abbreviations) would you expect to be used to tie the content to a specific statute or framework?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_517',
#   'question': "BNSS_to_CrPC_517 currently has an empty 'text' field; what types of data should be added to define a usable cross-reference between BNSS and the CrPC?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_517',
#   'question': "What is the preferred canonical CrPC reference format you would apply in BNSS_to_CrPC_517 (for example, 'CrPC, s. 161')?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_517',
#   'question': 'Which metadata fields should accompany the mapping in BNSS_to_CrPC_517 to uniquely identify the BNSS entry and the CrPC provision it maps to?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_517',
#   'question': 'If you were to populate BNSS_to_CrPC_517, what would be the minimal set of elements required to support automated lookups from BNSS identifiers to CrPC sections?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_517',
#   'question': 'What validation rules would you implement to ensure future content added to BNSS_to_CrPC_517 remains consistent with CrPC section numbering and BNSS identifiers?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_339',
#   'question': 'In BNSS_to_CrPC_339, is the "text" field non-empty?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_339',
#   'question': 'What is the value of the "doc_id" field for BNSS_to_CrPC_339?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_339',
#   'question': 'What does the "metadata" field contain in BNSS_to_CrPC_339?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_339',
#   'question': 'Does BNSS_to_CrPC_339 have any non-empty metadata entries?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_339',
#   'question': "Is there any substantive legal content available in the BNSS_to_CrPC_339 chunk's text?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_35',
#   'question': 'What is the formal law title or act name referenced in chunk BSA_to_IEA_35?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_35',
#   'question': 'Does chunk BSA_to_IEA_35 contain defined terms, and if so, what are their definitions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_35',
#   'question': 'What are the section numbers, article numbers, or headings that appear in chunk BSA_to_IEA_35?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_35',
#   'question': 'Are there any cross-references to other statutes or regulations in chunk BSA_to_IEA_35? If yes, specify them.',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_35',
#   'question': 'What is the stated effective date or enforcement date within chunk BSA_to_IEA_35?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_469',
#   'question': 'What is the value of the "chunk_id" field in this JSON chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_469',
#   'question': 'What is the value of the "doc_id" field in this JSON chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_469',
#   'question': 'What is the value of the "text" field in this JSON chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_469',
#   'question': 'What is the structure and content of the "metadata" field in this JSON chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_469',
#   'question': 'If you needed to reference this chunk in a legal database, which identifier from the JSON would you use as the primary key?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_191',
#   'question': "What is the exact value of the 'chunk_id' field for this dataset entry?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_191',
#   'question': 'Which field in this chunk’s JSON is currently empty, signaling missing legal text content?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_191',
#   'question': "In BNSS_to_CrPC_191, what does the 'CrPC' portion of the identifier most likely reference in a legal data context?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_191',
#   'question': 'If you were to populate the BNSS_to_CrPC_191 chunk with statutory text, what convention would you use to insert section numbers or abbreviations to tie to specific provisions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_191',
#   'question': 'What additional metadata would you include with BNSS_to_CrPC_191 to ensure future question generation can be accurately aligned with the intended legal topic?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_307',
#   'question': 'In the BNSS_to_CrPC_307 mapping, what is being cross-referenced between BNSS terminology and CrPC provisions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_307',
#   'question': 'What CrPC section number is encoded in the BNSS_to_CrPC_307 identifier, and what does this imply about the linked provision?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_307',
#   'question': 'How should BNSS_to_CrPC_307 guide a practitioner when a BNSS term has no direct CrPC counterpart?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_307',
#   'question': 'What types of supplementary data would you expect BNSS_to_CrPC_307 to include to ensure accurate cross-referencing (e.g., definitions, equivalence rules, notes)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_307',
#   'question': 'What potential ambiguity should a database manager watch for when implementing BNSS_to_CrPC_307 across multiple jurisdictions or editions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (2)',
#   'question': 'What is the exact value of the "chunk_id" field for this legal text chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (2)',
#   'question': 'What is the value of the "doc_id" field in the provided chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (2)',
#   'question': 'What is the content of the "text" field in the chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (2)',
#   'question': 'What keys are present at the top level of the "metadata" object in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (2)',
#   'question': 'Is the "metadata" object non-empty in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_516',
#   'question': 'In the given JSON object, what is the value of the chunk_id for this legal text fragment?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_516',
#   'question': 'What is the value of the doc_id field for this chunk BNSS_to_CrPC_516?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_516',
#   'question': "Is there any textual content in the 'text' field of this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_516',
#   'question': "What is the value of the 'metadata' field for this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_516',
#   'question': "Does the 'text' content of this chunk include any section numbers, law titles, or abbreviations?",
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_62',
#   'question': 'List all section numbers referenced in chunk BSA_to_IEA_62 and provide the corresponding law titles or abbreviations.',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_62',
#   'question': 'Identify any abbreviations used in chunk BSA_to_IEA_62 and explain the terms they stand for.',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_62',
#   'question': 'What is the stated objective or purpose connected to the BSA-to-IEA transition in chunk BSA_to_IEA_62?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_62',
#   'question': 'Does chunk BSA_to_IEA_62 reference other statutes or regulations, and if so, which ones?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_62',
#   'question': 'Does chunk BSA_to_IEA_62 specify any effective dates, deadlines, or compliance timelines? If so, what are they?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_2(1)(u)',
#   'question': 'What is the value of the "chunk_id" field in the provided chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_2(1)(u)',
#   'question': 'Does the "text" field in the chunk contain any content?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_2(1)(u)',
#   'question': 'What is the value of the "doc_id" field for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_2(1)(u)',
#   'question': 'What is the content of the "metadata" field in the chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_2(1)(u)',
#   'question': 'Which legal code abbreviation appears in the "chunk_id" (e.g., CrPC)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_118',
#   'question': 'What is the chunk_id assigned to the legal text segment in this input?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_118',
#   'question': "Is there any substantive 'text' content provided for BNSS_to_CrPC_118 in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_118',
#   'question': 'What is the value of the doc_id field for BNSS_to_CrPC_118?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_118',
#   'question': "What does the 'metadata' field contain for BNSS_to_CrPC_118?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_118',
#   'question': "What is the status noted for the 'text' field in BNSS_to_CrPC_118 (empty vs populated)?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_331 (7)',
#   'question': 'What IPC section number is represented by the chunk_id BNS_to_IPC_331 (7) and what is the expected subject matter noted by this mapping?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_331 (7)',
#   'question': 'In a filled-out version of this chunk, what type of content would be present under BNS_to_IPC_331 (7) (e.g., text of IPC 331, amendments, or cross-references)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_331 (7)',
#   'question': 'Does the current chunk contain any substantive provisions, definitions, or penalties related to the IPC section indicated by the chunk_id?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_331 (7)',
#   'question': 'What cross-references to other sections or acts would you expect to accompany an IPC cross-reference chunk labeled BNS_to_IPC_331 (7)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_331 (7)',
#   'question': 'If you were to validate the alignment of this chunk with the IPC, what verification steps would you perform?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (6)',
#   'question': 'What is the exact chunk_id of this legal text fragment?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (6)',
#   'question': "What is the value of the doc_id field for chunk_id 'BNS_to_IPC_324 (6)'?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (6)',
#   'question': 'What is the value of the text field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (6)',
#   'question': 'What is the content of the metadata field for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_324 (6)',
#   'question': "List the top-level fields present in this chunk's JSON object.",
#   'collection': 'collection_map'},
# ...
#   'question': 'If BNSS_to_CrPC_163 is intended to map to a CrPC provision, which section or title is the target?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_163',
#   'question': 'What metadata beyond chunk_id BNSS_to_CrPC_163 should guide the generation of the five questions?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_163',
#   'question': 'Should the questions reference CrPC provisions (section numbers or titles) once the content is available for BNSS_to_CrPC_163?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_163',
#   'question': 'Is it acceptable to generate questions about data quality or the mapping purpose of BNSS_to_CrPC_163 given that the text is currently empty?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_52',
#   'question': 'In the identifier BNSS_to_CrPC_52, what do BNSS and CrPC stand for in a criminal-law context?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_52',
#   'question': 'What type of cross-reference or linkage is suggested by BNSS_to_CrPC_52 between BNSS and CrPC?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_52',
#   'question': 'What minimal metadata would clarify the legal scope of BNSS_to_CrPC_52 when the full text is unavailable (e.g., section names, jurisdiction, year)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_52',
#   'question': 'If BNSS_to_CrPC_52 represents a cross-code mapping, what structural elements would you expect to accompany it (e.g., a table of equivalents, explanatory notes)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_52',
#   'question': 'What steps would you take to verify any conclusions drawn from BNSS_to_CrPC_52 once the underlying text is supplied?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_11',
#   'question': 'What is the value of the "chunk_id" field in this input?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_11',
#   'question': 'What is the value of the "doc_id" field for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_11',
#   'question': 'What is the content of the "text" field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_11',
#   'question': 'How is the "metadata" field structured in this chunk (e.g., its keys and values)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_11',
#   'question': 'Does the "text" field in this chunk contain any legal text?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_4',
#   'question': 'In the chunk identified as BSA_to_IEA_4, is there a defined term explaining what BSA and IEA stand for?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_4',
#   'question': 'Does BSA_to_IEA_4 contain a transitional provision detailing when the BSA is superseded by the IEA?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_4',
#   'question': 'Are there cross-references to other statutes or sections within BSA_to_IEA_4, and if so, which ones are named?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_4',
#   'question': 'Does the text of BSA_to_IEA_4 establish a deadline for implementation or compliance?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_4',
#   'question': 'Are penalties, remedies, or enforcement provisions specified in BSA_to_IEA_4 for non-compliance?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_127 (8)',
#   'question': 'What is the exact chunk_id of the law text this prompt refers to?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_127 (8)',
#   'question': 'What is the value of the doc_id field in the provided chunk JSON?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_127 (8)',
#   'question': 'What is the value of the text field in the provided chunk JSON?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_127 (8)',
#   'question': 'Which key appears inside the metadata object of the chunk JSON?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_127 (8)',
#   'question': "How many questions are specified to be generated for this chunk as per the user's instruction?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_45',
#   'question': 'What is the chunk_id assigned to this data segment?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_45',
#   'question': 'What is the value of the doc_id field in this JSON chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_45',
#   'question': 'What is the textual content stored in the text field for BNSS_to_CrPC_45?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_45',
#   'question': 'What is the data type and contents of the metadata field present in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_45',
#   'question': 'Are there any entries within the metadata object for this chunk, and if so, what keys do they contain?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (4)',
#   'question': "From the chunk_id 'BNS_to_IPC_341 (4)', which law code and section are designated as the target?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (4)',
#   'question': "In this chunk_id, what does the acronym 'IPC' refer to and what is its general domain of law?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (4)',
#   'question': "What is a plausible interpretation for the '(4)' suffix in 'BNS_to_IPC_341 (4)' when organizing chunks?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (4)',
#   'question': "What does the 'BNS_to_' prefix suggest about the type of data transformation or cross-reference represented in this chunk_id?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_341 (4)',
#   'question': "Which jurisdiction's statutes would you search to locate the text corresponding to IPC 341 in this chunk_id?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_99',
#   'question': 'What two legal regimes are suggested by the chunk_id BNS_to_IPC_99 as a potential cross-reference?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_99',
#   'question': 'In the absence of any text in this chunk, which metadata fields should be consulted to determine its relevance (for example, doc_id, metadata, or section tags)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_99',
#   'question': 'What minimal context would allow you to craft five precise questions about a chunk labeled BNS_to_IPC_99 when the text is empty?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_99',
#   'question': "Explain how you would assess whether the chunk's label indicates a cross-reference between codes rather than a standalone provision.",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_99',
#   'question': 'If you could access external databases, what search queries would you use to locate the actual legal text corresponding to BNS_to_IPC_99?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_156',
#   'question': 'What is the value of the "chunk_id" for this legal text chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_156',
#   'question': 'What is the value of the "doc_id" field in this chunk\'s JSON?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_156',
#   'question': 'What is the value of the "text" field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_156',
#   'question': 'What does the "metadata" field contain for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_156',
#   'question': 'If you were to add the main legal content to this chunk, which field would you populate with that content?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_325',
#   'question': "What is the value of the 'chunk_id' field in the provided JSON?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_325',
#   'question': 'Which legal code is referenced by the suffix in the chunk_id BNSS_to_CrPC_325?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_325',
#   'question': "Is there any substantive law text present in the 'text' field of this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_325',
#   'question': 'List the top-level keys present in the JSON object for this chunk.',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_325',
#   'question': "What is the value of the 'doc_id' field in this input?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_381',
#   'question': 'What is the chunk_id of the provided legal data object?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_381',
#   'question': 'What is the value of the doc_id field for BNSS_to_CrPC_381?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_381',
#   'question': 'What is the content of the text field in BNSS_to_CrPC_381?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_381',
#   'question': 'Is the metadata field non-empty for BNSS_to_CrPC_381?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_381',
#   'question': 'Which fields are present in the BNSS_to_CrPC_381 record?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_35',
#   'question': 'What is the value of the "chunk_id" field in this JSON payload?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_35',
#   'question': 'What is the value of the "doc_id" field for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_35',
#   'question': 'What is the content of the "text" field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_35',
#   'question': 'What keys are present within the "metadata" object for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_35',
#   'question': 'Does this chunk contain any substantive legal text to analyze, based on the "text" field content?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(3)',
#   'question': 'What is the chunk_id assigned to the law-text fragment representing the BNS to IPC mapping at 3(3)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(3)',
#   'question': "What is the doc_id value for the chunk with chunk_id 'BNS_to_IPC_3(3)'?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(3)',
#   'question': "What is the text content for the chunk 'BNS_to_IPC_3(3)'?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(3)',
#   'question': "What fields are present in the metadata for the chunk 'BNS_to_IPC_3(3)', and what are their values?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_3(3)',
#   'question': "In the label 'BNS_to_IPC_3(3)', what does the notation 3(3) imply about the structure of this mapping in the data set?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_174',
#   'question': 'In the chunk_id "BNS_to_IPC_174", which two statutes or documents are implicated by a cross-reference from BNS to IPC, and what is their likely jurisdiction?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_174',
#   'question': 'What kind of legal content would you expect to find in a chunk labeled "BNS_to_IPC_174" (e.g., a cross-reference table, concordance, or amendment note)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_174',
#   'question': 'If this chunk provides a mapping from BNS to IPC, which IPC sections would you expect to be cited, and in which sequence?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_174',
#   'question': 'What metadata fields would you want accompanying the empty chunk "BNS_to_IPC_174" to support later validation and reconstruction (for example source_abbrev, target_abbrev, source_section, target_section, note)?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_174',
#   'question': 'Provide a minimal skeleton template for "BNS_to_IPC_174" that includes source_abbrev, source_section, target_abbrev, target_section, and description fields.',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_336 (4)',
#   'question': 'What is the exact value of the chunk_id for this data?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_336 (4)',
#   'question': 'What is the doc_id field value for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_336 (4)',
#   'question': 'What content is in the text field of this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_336 (4)',
#   'question': 'What keys exist inside the metadata object for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_336 (4)',
#   'question': 'Is the text field of this chunk empty or populated?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_490',
#   'question': 'What is the chunk_id value in the provided JSON chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_490',
#   'question': "Does the 'text' field in the BNSS_to_CrPC_490 chunk contain any content?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_490',
#   'question': "What is the value of the 'doc_id' field in this chunk?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_490',
#   'question': "What is the value of the 'metadata' field in BNSS_to_CrPC_490?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNSS_to_CrPC_490',
#   'question': "How many strings should the 'llm_questions' array contain for this chunk, per the user instructions?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_299',
#   'question': "In chunk_id BNS_to_IPC_299, what is the value of the 'doc_id' field in the JSON?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_299',
#   'question': "In chunk_id BNS_to_IPC_299, does the 'text' field contain any substantive law content?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_299',
#   'question': "In chunk_id BNS_to_IPC_299, what are the contents of the 'metadata' object as provided?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_299',
#   'question': "For chunk_id BNS_to_IPC_299, what is a sensible first step to populate its missing 'text' from primary sources (IPC or BNS references) and why?",
#   'collection': 'collection_map'},
#  {'q_id': 'BNS_to_IPC_299',
#   'question': 'If later text is added to chunk_id BNS_to_IPC_299, which concrete legal identifiers (section numbers, law titles, or abbreviations) should be included to make the questions uniquely tied to the content?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_161',
#   'question': 'What is the chunk_id of this dataset entry?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_161',
#   'question': 'Does the text field contain any substantive legal content in chunk BSA_to_IEA_161?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_161',
#   'question': 'What is the value of the doc_id field in this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_161',
#   'question': 'What does the metadata field contain for this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_161',
#   'question': 'Since the text is empty, what would be a reasonable approach to generating five questions tied to this chunk?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_56',
#   'question': 'What cross-reference between the BSA and the IEA is allegedly established in BSA_to_IEA_56?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_56',
#   'question': 'Which section in BSA_to_IEA_56 is designated as the source for IEA obligations arising from the BSA?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_56',
#   'question': 'Does BSA_to_IEA_56 specify an effective date for the cross-reference between the BSA and the IEA?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_56',
#   'question': 'What definitions are provided in BSA_to_IEA_56 for terms used in the BSA-IEA cross-reference?',
#   'collection': 'collection_map'},
#  {'q_id': 'BSA_to_IEA_56',
#   'question': 'What enforcement mechanism or remedies are described in BSA_to_IEA_56 for non-compliance with the BSA-IEA cross-reference?',
#   'collection': 'collection_map'},
#  ...]

# %% [markdown]
# ## Evaluation Results

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)

# %%
def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
def evaluate(all_questions, search_function):
    relevance_total = []

    for q in tqdm(all_questions):
        q_id = q['q_id']
        collection_origin = q['collection']
    
        # Run the search
        results = elastic_search_all(query=q['question'])
        chunks = results[collection_origin]
    
        # Compute relevance for this collection
        relevance = [d['chunk_id'] == q_id for d in chunks]
        relevance_total.append(relevance)

    return {
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %% [markdown]
# #### ElasticSearch Evaluation Results

# %%
evaluate(all_questions, lambda q: elastic_search_all(q['question']))
# Out:
# 100%|██████████| 6700/6700 [01:32<00:00, 72.24it/s]
# {'hit_rate': 0.6080597014925373, 'mrr': 0.5757641554134102}

# %% [markdown]
# #### VectorSearch Evaluation Results
